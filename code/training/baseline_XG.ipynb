# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
import xgboost as xgb
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import numpy as np


def load_data(file_name, col_name, log_path = '../output/output.txt'):
    """
    Read in input file and load data

    root_dir: a path for data directory
    datafile: a text file for saving output

    return: X and y dataframe
    """
    output_file = open(log_path, 'a')

    df = pd.read_csv(file_name)
    print("\n********** Data Summary **********\n")
    print(df.shape, "\n")
    print(df.head(3), "\n")
    print(df.info(), "\n")

    print("\n********** Data Summary **********\n", file=output_file)
    print(df.shape, "\n", file=output_file)
    print(df.head(3), "\n", file=output_file)
    print(df.info(), "\n", file=output_file)
    ## Remove duplicates if any and keep first occurrence
    # df.drop_duplicates(subset=['pmid'], keep='first', inplace=True)

    print("\n********** Data Shape after Removing Duplicates **********\n")
    print(df.shape, "\n")

    print("\n********** Data Shape after Removing Duplicates **********\n", file=output_file)
    print(df.shape, "\n", file=output_file)

    # if col_name == 'mix':
    #     df['mix'] = df['title'] + df['abstract']
    ## clean the sign column
    df['sign'] = df['sign'].apply(lambda x: str(x).split(' ')[0])
    df = df[df['sign'] != 'nan']

    df = df[['sign', col_name]]
    ## Check if any columns contain null values
    print("\n********** Count of Null Values for Each Column **********\n")
    print(df.isnull().sum(), "\n")

    print("\n********** Count of Null Values for Each Column **********\n", file=output_file)
    print(df.isnull().sum(), "\n", file=output_file)

    ## Drop instances including null values
    df = df.dropna()

    print("\n********** Data Shape after Removing Null Values **********\n")
    print(df.shape, "\n")

    print("\n********** Data Shape after Removing Null Values **********\n", file=output_file)
    print(df.shape, "\n", file=output_file)

    print("\n********** Class Label Distribution **********\n")
    print(df["sign"].value_counts())

    print("\n********** Class Label Distribution **********\n", file=output_file)
    print(df["sign"].value_counts(), file=output_file)
    ## Trim unnecessary spaces for strings
    df[col_name] = df[col_name].apply(lambda x: str(x).strip())

    ## Split into X and y (target)
    X, y = df.loc[:, col_name], df.loc[:, 'sign']
    output_file.close()
    return X, y


# Insert your code here

def preprocess_data(data,log_path = '../output/output.txt'):
    """
       Preprocess data with lowercase conversion, punctuation removal, tokenization, stemming

       X_data: X data in dataframe
       return: transformed dataframe

    """
    output_file = open(log_path, 'a')

    print("\n\n********** Pre-processing Data **********\n")
    print("\n\n********** Pre-processing Data **********\n", file=output_file)

    ## Make sure that data type is string
    X_data = data.astype(str)

    ## 1. convert all characters to lowercase
    X_data = X_data.map(lambda x: x.lower())

    ## 2. remove punctuation
    X_data = X_data.str.replace('[^\w\s]', '')

    ## 3. tokenize sentence
    X_data = X_data.apply(nltk.word_tokenize)

    ## 4. remove stopwords
    stopword_list = stopwords.words("english")
    X_data = X_data.apply(lambda x: [word for word in x if word not in stopword_list])

    ## 5. stemming
    stemmer = PorterStemmer()
    X_data = X_data.apply(lambda x: [stemmer.stem(y) for y in x])

    ## 6. removing unnecessary space
    X_data = X_data.apply(lambda x: " ".join(x))
    output_file.close()

    return X_data
# Out:
# <>:110: SyntaxWarning: invalid escape sequence '\w'
# <>:110: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/ht/b8yjqyzj437bhml46pc2sxzm0000gn/T/ipykernel_53920/755885958.py:110: SyntaxWarning: invalid escape sequence '\w'
#   X_data = X_data.str.replace('[^\w\s]', '')
# [nltk_data] Downloading package punkt to /Users/jimmy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/jimmy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/jimmy/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/jimmy/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
data_path = '../data/okcupid_profiles.csv'
col_name = 'essay0'
model_name = 'Logistic'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X, y = load_data(data_path, col_name)
encoding = {}
elements = {
    "leo":0,
    "aries":0,
    "sagittarius":0,
    "cancer":1,
    "scorpio":1,
    "pisces": 1,
    "gemini":2,
    "libra": 2,
    "aquarius":2,
    "taurus": 3,
    "virgo": 3,
    "capricorn": 3
}
for i in range(len(y.unique())):
    encoding[y.unique()[i]] = i
def label_encode(x):
    # return math.sqrt(x)
    return encoding[x]
def element_encode(x):
    # return math.sqrt(x)
    return elements[x]
y = np.array(list(map(label_encode, y)))

Xp = preprocess_data(X)
X_train, X_test, y_train, y_test = train_test_split(Xp, y, test_size=0.2, random_state=5, stratify=y)

vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)
# Out:
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
#
# ********** Count of Null Values for Each Column **********
#
# sign         0
# essay0    4094
# dtype: int64
#
#
# ********** Data Shape after Removing Null Values **********
#
# (44796, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# leo            4009
# gemini         3968
# libra          3870
# cancer         3830
# virgo          3804
# taurus         3784
# scorpio        3781
# aries          3673
# sagittarius    3629
# pisces         3614
# aquarius       3576
# capricorn      3258
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********

# %%
model = xgb.XGBClassifier()
model.fit(X_train, y_train)


# model = LogisticRegression(random_state=0)
# model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# os.rename('../output/output.txt', f'../output/baseline_{col_name}_{model_name}.txt')

# %%
# Reverse key-value pairs
reversed_labels = {count: label for label, count in encoding.items()}

def reverse_label(x):
    return reversed_labels[x]
#Plotting the confusion matrix
# Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
y_pred2 = list(map(reverse_label, y_pred))
y_test2 = list(map(reverse_label, y_test))

# %%
print(classification_report(y_test2, y_pred2))
# y = list(map(reverse_label, y))

#Plotting the confusion matrix
# Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
cm = confusion_matrix(y_test2, y_pred2, labels=sorted(list(set(encoding))))
import matplotlib.pyplot as plt
import seaborn as sns

cm_df = pd.DataFrame(cm,
                     index =sorted(list(set(encoding))),
                     columns = sorted(list(set(encoding))))
plt.figure(figsize=(10,8))
sns.heatmap(cm_df, annot=True)
plt.title(f'{col_name}')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     aquarius       0.10      0.08      0.09       715
#        aries       0.09      0.08      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.06      0.07       651
#       gemini       0.09      0.13      0.10       794
#          leo       0.10      0.12      0.11       802
#        libra       0.09      0.10      0.09       774
#       pisces       0.06      0.05      0.06       723
#  sagittarius       0.08      0.07      0.08       726
#      scorpio       0.09      0.08      0.09       756
#       taurus       0.08      0.09      0.08       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.08      8960
# weighted avg       0.09      0.09      0.09      8960

# %%
preds = []
for i in range(10):
    data_path = '../data/okcupid_profiles.csv'
    col_name = f'essay{i}'
    
    X, y = load_data(data_path, col_name)
    encoding = {}
    elements = {
        "leo":0,
        "aries":0,
        "sagittarius":0,
        "cancer":1,
        "scorpio":1,
        "pisces": 1,
        "gemini":2,
        "libra": 2,
        "aquarius":2,
        "taurus": 3,
        "virgo": 3,
        "capricorn": 3
    }
    for i in range(len(y.unique())):
        encoding[y.unique()[i]] = i
    def label_encode(x):
        # return math.sqrt(x)
        return encoding[x]
    def element_encode(x):
        # return math.sqrt(x)
        return elements[x]
    y = np.array(list(map(label_encode, y)))
    
    Xp = preprocess_data(X)
    X_train, X_test, y_train, y_test = train_test_split(Xp, y, test_size=0.2, random_state=5, stratify=y)
    
    vectorizer = TfidfVectorizer()
    X_train = vectorizer.fit_transform(X_train)
    X_test = vectorizer.transform(X_test)
    
    model = xgb.XGBClassifier()
    model.fit(X_train, y_train)
    
    
    # model = LogisticRegression(random_state=0)
    # model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    # os.rename('../output/output.txt', f'../output/baseline_{col_name}_{model_name}.txt')
    # Reverse key-value pairs
    reversed_labels = {count: label for label, count in encoding.items()}
    
    def reverse_label(x):
        return reversed_labels[x]
    #Plotting the confusion matrix
    # Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
    y_pred2 = list(map(reverse_label, y_pred))
    y_test2 = list(map(reverse_label, y_test))
    print(classification_report(y_test4, y_pred4))
    # y = list(map(reverse_label, y))
    
    #Plotting the confusion matrix
    # Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
    cm2 = confusion_matrix(y_test2, y_pred2, labels=sorted(list(set(encoding))))
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    cm_df2 = pd.DataFrame(cm2,
                          index =sorted(list(set(encoding))),
                          columns = sorted(list(set(encoding))))
    plt.figure(figsize=(10,8))
    sns.heatmap(cm_df2, annot=True)
    plt.title(f'{col_name}')
    plt.ylabel('Actual Values')
    plt.xlabel('Predicted Values')
    preds.append(y_pred2)
    plt.savefig(f'../plots/xgb_{col_name}.png')
    plt.show()
    # os.rename('../output/output.txt', f'../output/baseline_{col_name}_{model_name}.txt')
# Out:
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
#
# ********** Count of Null Values for Each Column **********
#
# sign         0
# essay0    4094
# dtype: int64
#
# ********** Data Shape after Removing Null Values **********
#
# (44796, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# leo            4009
# gemini         3968
# libra          3870
# cancer         3830
# virgo          3804
# taurus         3784
# scorpio        3781
# aries          3673
# sagittarius    3629
# pisces         3614
# aquarius       3576
# capricorn      3258
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
#
# ********** Count of Null Values for Each Column **********
#
# sign         0
# essay1    5426
# dtype: int64
#
#
# ********** Data Shape after Removing Null Values **********
#
# (43464, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# leo            3910
# gemini         3834
# libra          3767
# cancer         3712
# taurus         3709
# virgo          3682
# scorpio        3626
# aries          3568
# pisces         3513
# sagittarius    3513
# aquarius       3478
# capricorn      3152
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
# ********** Count of Null Values for Each Column **********
#
# sign         0
# essay2    6849
# dtype: int64
#
#
# ********** Data Shape after Removing Null Values **********
#
# (42041, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# leo            3772
# gemini         3692
# libra          3652
# taurus         3588
# cancer         3582
# virgo          3572
# scorpio        3502
# aries          3445
# sagittarius    3399
# pisces         3394
# aquarius       3365
# capricorn      3078
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
#
# ********** Count of Null Values for Each Column **********
#
# sign         0
# essay3    8062
# dtype: int64
#
#
# ********** Data Shape after Removing Null Values **********
#
# (40828, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# leo            3640
# gemini         3585
# libra          3577
# cancer         3526
# virgo          3477
# taurus         3443
# scorpio        3410
# sagittarius    3320
# aries          3315
# pisces         3306
# aquarius       3235
# capricorn      2994
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
#
# ********** Count of Null Values for Each Column **********
# sign         0
# essay4    7589
# dtype: int64
#
#
# ********** Data Shape after Removing Null Values **********
#
# (41301, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# leo            3711
# gemini         3650
# libra          3583
# cancer         3535
# taurus         3527
# virgo          3493
# scorpio        3455
# sagittarius    3378
# aries          3377
# pisces         3323
# aquarius       3272
# capricorn      2997
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
#
# ********** Count of Null Values for Each Column **********
#
# sign         0
# essay5    7598
# dtype: int64
#
#
# ********** Data Shape after Removing Null Values **********
#
# (41292, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# leo            3679
# gemini         3637
# libra          3582
# cancer         3536
# virgo          3521
# taurus         3518
# scorpio        3451
# aries          3392
# pisces         3331
# sagittarius    3329
# aquarius       3290
# capricorn      3026
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
# ...
# taurus         3425
# cancer         3415
# virgo          3409
# scorpio        3342
# aries          3318
# pisces         3245
# sagittarius    3234
# aquarius       3151
# capricorn      2940
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
# ********** Count of Null Values for Each Column **********
#
# sign          0
# essay8    14272
# dtype: int64
#
#
# ********** Data Shape after Removing Null Values **********
#
# (34618, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# leo            3074
# gemini         3031
# libra          3030
# cancer         2985
# virgo          2953
# taurus         2927
# scorpio        2905
# sagittarius    2843
# aries          2841
# pisces         2810
# aquarius       2723
# capricorn      2496
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960
# ********** Data Summary **********
#
# (59946, 31)
#
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
#
#      drinks      drugs                       education     ethnicity  ...  \
# 0  socially      never   working on college/university  asian, white  ...
# 1     often  sometimes           working on space camp         white  ...
# 2  socially        NaN  graduated from masters program           NaN  ...
#
#                                               essay0  \
# 0  about me:  i would love to think that i was so...
# 1  i am a chef: this is what that means. 1. i am ...
# 2  i'm not ashamed of much, but writing public te...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
#
#                                               essay2  \
# 0  making people laugh. ranting about a good salt...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
#
#                                               essay4  \
# 0  books: absurdistan, the republic, of mice and ...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
#
#                                               essay5  \
# 0                  food. water. cell phone. shelter.
# 1  delicious porkness in all of its glories. my b...
# 2  movement conversation creation contemplation t...
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
#
#                                               essay9
# 0  you want to be swept off your feet! you are ti...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
#
# [3 rows x 31 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
#  18  sign         48890 non-null  object
#  19  smokes       54434 non-null  object
#  20  speaks       59896 non-null  object
#  21  essay0       54458 non-null  object
#  22  essay1       52374 non-null  object
#  23  essay2       50308 non-null  object
#  24  essay3       48470 non-null  object
#  25  essay4       49409 non-null  object
#  26  essay5       49096 non-null  object
#  27  essay6       46175 non-null  object
#  28  essay7       47495 non-null  object
#  29  essay8       40721 non-null  object
#  30  essay9       47343 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB
#
# ********** Data Shape after Removing Duplicates **********
#
# (59946, 31)
#
#
# ********** Count of Null Values for Each Column **********
#
# sign         0
# essay9    9190
# dtype: int64
#
# ********** Data Shape after Removing Null Values **********
#
# (39700, 2)
#
#
# ********** Class Label Distribution **********
#
# sign
# gemini         3526
# leo            3526
# libra          3472
# cancer         3411
# taurus         3380
# virgo          3363
# scorpio        3335
# aries          3249
# pisces         3205
# sagittarius    3190
# aquarius       3152
# capricorn      2891
# Name: count, dtype: int64
#
#
# ********** Pre-processing Data **********
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960

# %%
from collections import Counter

def mode(lst):
    # Count the occurrences of each string
    counts = Counter(lst)
    # Find the maximum count
    max_count = max(counts.values())
    # Get the modes (strings with maximum count)
    mode_values = [key for key, value in counts.items() if value == max_count]

    # Check if there is a mode
    if len(mode_values) == len(set(lst)):  # If all elements occur with the same frequency
        return "No mode"
    else:
        return mode_values

# %%
probs = model.predict_proba(X_test)
probs
# Out:
# array([[0.08120802, 0.09017862, 0.06844533, ..., 0.07939515, 0.13453391,
#         0.06149986],
#        [0.07690844, 0.05349503, 0.07410093, ..., 0.05639485, 0.07336175,
#         0.12487282],
#        [0.07412735, 0.06851746, 0.07855059, ..., 0.07528324, 0.07755952,
#         0.06660108],
#        ...,
#        [0.27879366, 0.05790253, 0.04948116, ..., 0.06902447, 0.0661682 ,
#         0.05697349],
#        [0.11651345, 0.0681889 , 0.05681   , ..., 0.12568313, 0.10289194,
#         0.03695709],
#        [0.12309197, 0.04027312, 0.03155968, ..., 0.04227633, 0.10711433,
#         0.0770905 ]], dtype=float32)

# %%
new_preds = []
for i in range(len(y_pred)):
    predsi = [u[i] for u in preds]
    new_preds.append(mode(predsi))
print(classification_report(y_test4, new_preds))
# y = list(map(reverse_label, y))

#Plotting the confusion matrix
# Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
cm2 = confusion_matrix(y_test2, new_preds, labels=sorted(list(set(encoding))))
import matplotlib.pyplot as plt
import seaborn as sns

cm_df2 = pd.DataFrame(cm2,
                      index =sorted(list(set(encoding))),
                      columns = sorted(list(set(encoding))))
plt.figure(figsize=(10,8))
sns.heatmap(cm_df2, annot=True)
plt.title(f'{col_name}')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
# preds.append(y_pred2)
# plt.savefig(f'../plots/xgb_{col_name}.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 new_preds = []
#       2 for i in range(len(y_pred)):
# ----> 3     predsi = [u[i] for u in preds]
#       4     new_preds.append(mode(predsi))
#       5 print(classification_report(y_test4, new_preds))
#
# IndexError: list index out of range

# %%
## XGB with TFID
model2 = xgb.XGBClassifier(max_depth=12)
model2.fit(X_train, y_train)


# model = LogisticRegression(random_state=0)
# model.fit(X_train, y_train)
y_pred3 = model2.predict(X_test)
# os.rename('../output/output.txt', f'../output/baseline_{col_name}_{model_name}.txt')

# %%
# Reverse key-value pairs
reversed_labels = {count: label for label, count in encoding.items()}

def reverse_label(x):
    return reversed_labels[x]
#Plotting the confusion matrix
# Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
y_pred4 = list(map(reverse_label, y_pred3))
y_test4 = list(map(reverse_label, y_test))
print(classification_report(y_test4, y_pred4))
# y = list(map(reverse_label, y))

#Plotting the confusion matrix
# Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
cm2 = confusion_matrix(y_test4, y_pred4, labels=sorted(list(set(encoding))))
import matplotlib.pyplot as plt
import seaborn as sns

cm_df2 = pd.DataFrame(cm2,
                     index =sorted(list(set(encoding))),
                     columns = sorted(list(set(encoding))))
plt.figure(figsize=(10,8))
sns.heatmap(cm_df2, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     aquarius       0.09      0.07      0.08       715
#        aries       0.09      0.07      0.08       735
#       cancer       0.08      0.08      0.08       766
#    capricorn       0.09      0.08      0.08       651
#       gemini       0.10      0.13      0.11       794
#          leo       0.09      0.11      0.10       802
#        libra       0.08      0.09      0.08       774
#       pisces       0.08      0.07      0.07       723
#  sagittarius       0.08      0.08      0.08       726
#      scorpio       0.10      0.09      0.09       756
#       taurus       0.10      0.10      0.10       757
#        virgo       0.08      0.08      0.08       761
#
#     accuracy                           0.09      8960
#    macro avg       0.09      0.09      0.09      8960
# weighted avg       0.09      0.09      0.09      8960

# %% [markdown]
# ## Transformer Embedding
